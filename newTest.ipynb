# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import streamlit as st

# %%
source="""<div id="categoryOptions"><select data-placeholder="e.g. Marketing" id="select_category" name="select_category" class="form-control chosen-select default-chosen" multiple="" tabindex="-1" style="display: none;">
            <option value=".net">.NET</option>
                <option value=".net%20development">.NET Development</option>
                <option value="3d%20printing">3D Printing</option>
                <option value="3ds%20max">3ds Max</option>
                <option value="ajax">AJAX</option>
                <option value="ansa">ANSA</option>
                <option value="ansys">ANSYS</option>
                <option value="apis">APIs</option>
                <option value="arm%20microcontroller">ARM Microcontroller</option>
                <option value="asp.net">ASP.NET</option>
                <option value="ableton%20live">Ableton Live</option>
                <option value="accounts">Accounts</option>
                <option value="acting">Acting</option>
                <option value="acting%20audition">Acting Audition</option>
                <option value="acting%20technique">Acting technique</option>
                <option value="adobe%20after%20effects">Adobe After Effects</option>
                <option value="adobe%20audition">Adobe Audition</option>
                <option value="adobe%20creative%20suite">Adobe Creative Suite</option>
                <option value="adobe%20dreamweaver">Adobe Dreamweaver</option>
                <option value="adobe%20flash">Adobe Flash</option>
                <option value="adobe%20illustrator">Adobe Illustrator</option>
                <option value="adobe%20indesign">Adobe Indesign</option>
                <option value="adobe%20photoshop">Adobe Photoshop</option>
                <option value="adobe%20photoshop%20lightroom%20cc">Adobe Photoshop Lightroom CC</option>
                <option value="adobe%20premiere%20pro">Adobe Premiere Pro</option>
                <option value="adobe%20xd">Adobe XD</option>
                <option value="advanced%20excel">Advanced Excel</option>
                <option value="aerospace">Aerospace Engineering</option>
                <option value="agriculture%20and%20food%20engineering">Agriculture &amp; Food Engineering</option>
                <option value="algorithms">Algorithms</option>
                <option value="allegro%20software">Allegro Software</option>
                <option value="amazon%20web%20server%20(aws)">Amazon Web Server (AWS)</option>
                <option value="amazon%20web%20services%20(aws)">Amazon Web Services (AWS)</option>
                <option value="american%20english">American English</option>
                <option value="analog%20and%20digital%20circuits">Analog And Digital Circuits</option>
                <option value="analytics">Analytics</option>
                <option value="anchoring">Anchoring</option>
                <option value="android">Android</option>
                <option value="android%20app%20development">Android App Development</option>
                <option value="angular%202.0">Angular 2.0</option>
                <option value="angular%207.0">Angular 7.0</option>
                <option value="angular.js%20development">Angular.js Development</option>
                <option value="angularjs">AngularJS</option>
                <option value="animation">Animation</option>
                <option value="apache">Apache</option>
                <option value="arcgis">ArcGIS</option>
                <option value="architecture">Architecture</option>
                <option value="arduino">Arduino</option>
                <option value="articulate%20360">Articulate 360</option>
                <option value="articulate%20storyline">Articulate Storyline</option>
                <option value="artificial%20intelligence%20(ai)">Artificial Intelligence (AI)</option>
                <option value="artificial%20intelligence">Artificial intelligence</option>
                <option value="assamese%20proficiency%20(spoken)">Assamese Proficiency (Spoken)</option>
                <option value="assamese%20proficiency%20(written)">Assamese Proficiency (Written)</option>
                <option value="atmel%20avr">Atmel AVR</option>
                <option value="audacity">Audacity</option>
                <option value="audio%20editing">Audio Editing</option>
                <option value="audio%20making">Audio Making</option>
                <option value="audio%20making%2Fediting">Audio Making/Editing</option>
                <option value="auditing">Auditing</option>
                <option value="autocad">AutoCAD</option>
                <option value="autodesk%20123d%20design">Autodesk 123D design</option>
                <option value="autodesk%20alias">Autodesk Alias</option>
                <option value="autodesk%20cfd">Autodesk CFD</option>
                <option value="autodesk%20fusion%20360">Autodesk Fusion 360</option>
                <option value="autodesk%20inventor">Autodesk Inventor</option>
                <option value="autodesk%20maya">Autodesk Maya</option>
                <option value="autodesk%20revit">Autodesk Revit</option>
                <option value="autodesk%20sketchbook">Autodesk SketchBook</option>
                <option value="automobile%20engineering">Automobile Engineering</option>
                <option value="bim%20(building%20information%20modeling)">BIM (Building Information Modeling)</option>
                <option value="backend%20development">Backend Development</option>
                <option value="bank">Bank</option>
                <option value="bash">Bash</option>
                <option value="bengali%20proficiency%20(spoken)">Bengali Proficiency (Spoken)</option>
                <option value="bengali%20proficiency%20(written)">Bengali Proficiency (Written)</option>
                <option value="big%20data">Big Data</option>
                <option value="bioinformatics">Bioinformatics</option>
                <option value="biology">Biology</option>
                <option value="biotech">Biotechnology Engineering</option>
                <option value="blender%203d">Blender 3D</option>
                <option value="blockchain">Blockchain</option>
                <option value="blockchain%20development">Blockchain Development</option>
                <option value="blogging">Blogging</option>
                <option value="bodo%20proficiency(spoken)">Bodo Proficiency(Spoken)</option>
                <option value="bodo%20proficiency(written)">Bodo Proficiency(Written)</option>
                <option value="bootstrap">Bootstrap</option>
                <option value="brand%20management">Brand Management</option>
                <option value="british%20english">British English</option>
                <option value="business%20analysis">Business Analysis</option>
                <option value="business%20development">Business Development</option>
                <option value="business%20research">Business Research</option>
                <option value="mba">Business/MBA</option>
                <option value="c%20programming">C Programming</option>
                <option value="c%23">C#</option>
                <option value="c%23.net">C#.NET</option>
                <option value="c%2B%2B%20programming">C++ Programming</option>
                <option value="ca%20articleship">CA Articleship</option>
                <option value="cad">CAD</option>
                <option value="cad%20design">CAD Design</option>
                <option value="cam">CAM</option>
                <option value="ccna">CCNA</option>
                <option value="ci%2Fcd">CI/CD</option>
                <option value="clo3d">CLO3D</option>
                <option value="cma%20articleship">CMA Articleship</option>
                <option value="cms">CMS</option>
                <option value="cnc%20programming">CNC Programming</option>
                <option value="comsol">COMSOL</option>
                <option value="converge">CONVERGE</option>
                <option value="crm">CRM</option>
                <option value="cs%20articleship">CS Articleship</option>
                <option value="css">CSS</option>
                <option value="calligraphy">Calligraphy</option>
                <option value="campus%20ambassador">Campus Ambassador</option>
                <option value="canva">Canva</option>
                <option value="catia">Catia</option>
                <option value="chartered%20accountancy%20(ca)">Chartered Accountancy (CA)</option>
                <option value="chemical">Chemical Engineering</option>
                <option value="chemistry">Chemistry</option>
                <option value="cinematography">Cinematography</option>
                <option value="circuit%20design">Circuit Design</option>
                <option value="civil">Civil Engineering</option>
                <option value="client%20relationship">Client Relationship</option>
                <option value="client%20servicing">Client Servicing</option>
                <option value="client%20interaction">Client interaction</option>
                <option value="clip%20studio%20paint">Clip Studio Paint</option>
                <option value="cloud%20computing">Cloud Computing</option>
                <option value="cloud%20firestore">Cloud Firestore</option>
                <option value="codeigniter">CodeIgniter</option>
                <option value="colour%20theory%20for%20designers">Colour Theory for Designers</option>
                <option value="commerce">Commerce</option>
                <option value="company%20secretary%20(cs)">Company Secretary (CS)</option>
                <option value="compensation%20management">Compensation management</option>
                <option value="computational%20neuroscience">Computational Neuroscience</option>
                <option value="computer%20networking">Computer Networking</option>
                <option value="computer%20networks">Computer Networks</option>
                <option value="computer%20science">Computer Science</option>
                <option value="computer%20vision">Computer Vision</option>
                <option value="content%20marketing">Content Marketing</option>
                <option value="content%20writing">Content Writing</option>
                <option value="copywriting">Copywriting</option>
                <option value="coreldraw">CorelDRAW</option>
                <option value="creative%20design">Creative Design</option>
                <option value="creative%20writing">Creative Writing</option>
                <option value="culinary%20arts">Culinary Arts</option>
                <option value="customer%20service">Customer Service</option>
                <option value="cyber%20security">Cyber Security</option>
                <option value="dart">Dart</option>
                <option value="data%20analysis">Data Analysis</option>
                <option value="data%20analytics">Data Analytics</option>
                <option value="data%20entry">Data Entry</option>
                <option value="data%20science">Data Science</option>
                <option value="data%20structures">Data Structures</option>
                <option value="database%20building">Database Building</option>
                <option value="database%20testing">Database Testing</option>
                <option value="deep%20learning">Deep Learning</option>
                <option value="design">Design</option>
                <option value="design%20thinking">Design Thinking</option>
                <option value="devops">DevOps</option>
                <option value="dietetics%2Fnutrition">Dietetics/Nutrition</option>
                <option value="digital%20advertising">Digital Advertising</option>
                <option value="digital%20art">Digital Art</option>
                <option value="digital%20marketing">Digital Marketing</option>
                <option value="digital%20signal%20processing">Digital Signal Processing</option>
                <option value="digitalocean">DigitalOcean</option>
                <option value="display%20advertising">Display Advertising</option>
                <option value="django">Django</option>
                <option value="docker">Docker</option>
                <option value="drupal">Drupal</option>
                <option value="eagle">EAGLE</option>
                <option value="erp%20implementation%20and%20deployment">ERP Implementation and Deployment</option>
                <option value="eclipse%20(ide)">Eclipse (IDE)</option>
                <option value="econometrics">Econometrics</option>
                <option value="economics">Economics</option>
                <option value="editorial">Editorial</option>
                <option value="effective%20communication">Effective Communication</option>
                <option value="elasticsearch">Elasticsearch</option>
                <option value="electrical">Electrical Engineering</option>
                <option value="electronjs">ElectronJS</option>
                <option value="electronics">Electronics Engineering</option>
                <option value="email%20marketing">Email Marketing</option>
                <option value="embedded%20systems">Embedded Systems</option>
                <option value="employment%20engagement">Employment engagement</option>
                <option value="energy%20science%20and%20engineering">Energy Science &amp; Engineering</option>
                <option value="engineering">Engineering</option>
                <option value="engineering%20design">Engineering Design</option>
                <option value="engineering%20drawing">Engineering Drawing</option>
                <option value="engineering%20physics">Engineering Physics</option>
                <option value="engineering%20surveying">Engineering Surveying</option>
                <option value="english%20proficiency%20(spoken)">English Proficiency (Spoken)</option>
                <option value="english%20proficiency%20(written)">English Proficiency (Written)</option>
                <option value="enterprise%20resource%20planning(erp)">Enterprise Resource Planning(ERP)</option>
                <option value="environmental%20sciences">Environmental Sciences</option>
                <option value="estimation%20(estimating)">Estimation (estimating)</option>
                <option value="ethereum">Ethereum</option>
                <option value="ethical%20hacking">Ethical Hacking</option>
                <option value="event%20management">Event Management</option>
                <option value="express.js">Express.js</option>
                <option value="fl%20studio%20(formerly%20known%20as%20fruityloops)">FL Studio (formerly known as FruityLoops)</option>
                <option value="facebook%20ads">Facebook Ads</option>
                <option value="facebook%20marketing">Facebook Marketing</option>
                <option value="fashion%20design">Fashion Design</option>
                <option value="fashion%20designing">Fashion Designing</option>
                <option value="fashion%20styling">Fashion Styling</option>
                <option value="fastapi">FastAPI</option>
                <option value="figma">Figma</option>
                <option value="film%20making">Film Making</option>
                <option value="final%20cut%20pro">Final Cut Pro</option>
                <option value="finance">Finance</option>
                <option value="financial%20modeling">Financial Modeling</option>
                <option value="financial%20literacy">Financial literacy</option>
                <option value="firebase">Firebase</option>
                <option value="firebase%20cloud%20messaging">Firebase Cloud Messaging</option>
                <option value="flask">Flask</option>
                <option value="flutter">Flutter</option>
                <option value="flutter%20development">Flutter Development</option>
                <option value="french%20proficiency%20(spoken)">French Proficiency (spoken)</option>
                <option value="french%20proficiency%20(written)">French Proficiency (written)</option>
                <option value="front%20end%20development">Front End Development</option>
                <option value="full%20stack%20development">Full Stack Development</option>
                <option value="fundraising">Fundraising</option>
                <option value="gimp">GIMP</option>
                <option value="gui%20testing">GUI Testing</option>
                <option value="game%20design">Game Design</option>
                <option value="game%20development">Game Development</option>
                <option value="general%20management">General Management</option>
                <option value="german%20proficiency%20(spoken)">German Proficiency (Spoken)</option>
                <option value="german%20proficiency%20(written)">German Proficiency (Written)</option>
                <option value="git">Git</option>
                <option value="github">GitHub</option>
                <option value="golang">Golang</option>
                <option value="google%20adwords">Google AdWords</option>
                <option value="google%20analytics">Google Analytics</option>
                <option value="google%20cloud%20computing">Google Cloud Computing</option>
                <option value="google%20sketchup%20">Google SketchUp </option>
                <option value="google%20suite%20(g%20suite)">Google Suite (G Suite)</option>
                <option value="google%20workspace">Google Workspace</option>
                <option value="government">Government</option>
                <option value="graphic%20design">Graphic Design</option>
                <option value="guitar">Guitar</option>
                <option value="gujarati%20proficiency%20(spoken)">Gujarati Proficiency (Spoken)</option>
                <option value="gujarati%20proficiency%20(written)">Gujarati Proficiency (Written)</option>
                <option value="hr%20analytics">HR Analytics</option>
                <option value="hr%20branding">HR branding</option>
                <option value="hris">HRIS</option>
                <option value="html">HTML</option>
                <option value="html%26css">HTML&amp;CSS</option>
                <option value="hadoop">Hadoop</option>
                <option value="helioscope">HelioScope</option>
                <option value="hibernate%20(java)">Hibernate (Java)</option>
                <option value="hindi%20proficiency%20(spoken)">Hindi Proficiency (Spoken)</option>
                <option value="hindi%20proficiency%20(written)">Hindi Proficiency (Written)</option>
                <option value="history">History</option>
                <option value="holiday%20package%20design">Holiday Package Design</option>
                <option value="hospitality">Hospitality</option>
                <option value="hotel%20management">Hotel Management</option>
                <option value="hr">Human Resources (HR)</option>
                <option value="humanities">Humanities</option>
                <option value="hyperledger">Hyperledger</option>
                <option value="image%20processing">Image Processing</option>
                <option value="industrial%20and%20production%20engineering">Industrial &amp; Production Engineering</option>
                <option value="industrial%20design">Industrial Design</option>
                <option value="industrial%20automation">Industrial automation</option>
                <option value="information%20technology">Information Technology</option>
                <option value="information%20architecture">Information architecture</option>
                <option value="inkscape">Inkscape</option>
                <option value="instagram%20marketing">Instagram Marketing</option>
                <option value="instrumentation%20and%20control%20engineering">Instrumentation &amp; Control Engineering</option>
                <option value="interior%20design">Interior Design</option>
                <option value="international">International</option>
                <option value="internet%20of%20things%20(iot)">Internet of Things (IoT)</option>
                <option value="interpersonal%20skills">Interpersonal skills</option>
                <option value="investing">Investing</option>
                <option value="ionic">Ionic</option>
                <option value="j2ee">J2EE</option>
                <option value="json">JSON</option>
                <option value="jsp">JSP</option>
                <option value="java">Java</option>
                <option value="javascript">JavaScript</option>
                <option value="javascript%20development">Javascript Development</option>
                <option value="jenkins">Jenkins</option>
                <option value="jira">Jira</option>
                <option value="journalism">Journalism</option>
                <option value="kannada">Kannada</option>
                <option value="kannada%20proficiency%20(spoken)">Kannada Proficiency (Spoken)</option>
                <option value="kannada%20proficiency%20(written)">Kannada Proficiency (Written)</option>
                <option value="kashmiri%20proficiency%20(spoken)">Kashmiri Proficiency (Spoken)</option>
                <option value="kashmiri%20proficiency%20(written)">Kashmiri Proficiency (written)</option>
                <option value="keyshot">KeyShot</option>
                <option value="konkani%20proficiency%20(spoken)">Konkani Proficiency (Spoken)</option>
                <option value="korean%20proficiency%20(spoken)">Korean Proficiency (Spoken)</option>
                <option value="korean%20proficiency%20(written)">Korean Proficiency (Written)</option>
                <option value="kotlin">Kotlin</option>
                <option value="kubernetes">Kubernetes</option>
                <option value="laravel">LARAVEL</option>
                <option value="latex">LaTeX</option>
                <option value="labour%20laws">Labour laws</option>
                <option value="law">Law</option>
                <option value="lead%20generation">Lead Generation</option>
                <option value="legal%20research">Legal Research</option>
                <option value="linear%20programming">Linear Programming</option>
                <option value="linkedin%20marketing">LinkedIn Marketing</option>
                <option value="linux">Linux</option>
                <option value="matlab">MATLAB</option>
                <option value="mean%2Fmern%20stack">MEAN/MERN Stack</option>
                <option value="ms%20sql%20server">MS SQL Server</option>
                <option value="ms-excel">MS-Excel</option>
                <option value="ms-office">MS-Office</option>
                <option value="ms-powerpoint">MS-PowerPoint</option>
                <option value="ms-word">MS-Word</option>
                <option value="machine%20learning">Machine Learning</option>
                <option value="malayalam%20proficiency%20(spoken)">Malayalam Proficiency (Spoken)</option>
                <option value="malayalam%20proficiency%20(written)">Malayalam Proficiency (Written)</option>
                <option value="manipuri%20proficiency%20(spoken)">Manipuri Proficiency (Spoken)</option>
                <option value="manipuri%20proficiency%20(written)">Manipuri Proficiency (Written)</option>
                <option value="manpower%20planning">Manpower Planning</option>
                <option value="manual%20testing">Manual Testing</option>
                <option value="manufacturing%20engineering">Manufacturing Engineering</option>
                <option value="marathi%20proficiency(spoken)">Marathi Proficiency(Spoken)</option>
                <option value="marathi%20proficiency(written)">Marathi Proficiency(Written)</option>
                <option value="market%20analysis">Market Analysis</option>
                <option value="market%20research">Market research</option>
                <option value="market%2Fbusiness%20research">Market/Business Research</option>
                <option value="marketing">Marketing</option>
                <option value="marketing%20campaigns%20">Marketing Campaigns </option>
                <option value="marketing%20programs%20">Marketing Programs </option>
                <option value="marketing%20strategies%20">Marketing Strategies </option>
                <option value="material%20science">Material Science</option>
                <option value="mathematics">Mathematics</option>
                <option value="mathematics%20and%20computing">Mathematics &amp; Computing</option>
                <option value="mechanical">Mechanical Engineering</option>
                <option value="mechatronics">Mechatronics</option>
                <option value="media">Media</option>
                <option value="medicine">Medicine</option>
                <option value="merchandise%20design">Merchandise Design</option>
                <option value="metallurgy">Metallurgical Engineering</option>
                <option value="microsoft%20azure">Microsoft Azure</option>
                <option value="microsoft%20powerapps">Microsoft PowerApps</option>
                <option value="microsoft%20project">Microsoft Project</option>
                <option value="microsoft%20visual%20studio">Microsoft Visual Studio</option>
                <option value="mobile%20app%20development">Mobile App Development</option>
                <option value="model%20view%20controller(mvc)">Model View Controller(MVC)</option>
                <option value="molecular%20biology%20techniques">Molecular Biology Techniques</option>
                <option value="molecular%20medicine">Molecular Medicine</option>
                <option value="mongodb">MongoDB</option>
                <option value="motion%20graphics">Motion Graphics</option>
                <option value="music">Music</option>
                <option value="mysql">MySQL</option>
                <option value="ngo">NGO</option>
                <option value="nx%20siemens%20(formerly%20unigraphics%20nx)">NX Siemens (formerly Unigraphics NX)</option>
                <option value="natural%20language%20processing%20(nlp)">Natural Language Processing (NLP)</option>
                <option value="naval%20and%20ocean">Naval Architecture and Ocean Engineeering</option>
                <option value="negotiation%20%26%20problem-solving">Negotiation &amp; Problem-solving</option>
                <option value="network%20engineering">Network Engineering</option>
                <option value="neural%20networks">Neural Networks</option>
                <option value="next%20generation%20sequencing%20(ngs)">Next Generation Sequencing (NGS)</option>
                <option value="next.js">Next.js</option>
                <option value="nginx">Nginx</option>
                <option value="nosql">NoSQL</option>
                <option value="node.js">Node.js</option>
                <option value="node.js%20development">Node.js Development</option>
                <option value="objective%20c">Objective C</option>
                <option value="odia%20proficiency(spoken)">Odia Proficiency(Spoken)</option>
                <option value="odia%20proficiency(written)">Odia Proficiency(Written)</option>
                <option value="odoo">Odoo</option>
                <option value="online%20teaching">Online Teaching</option>
                <option value="opencv">OpenCV</option>
                <option value="operations">Operations</option>
                <option value="oracle">Oracle</option>
                <option value="pcb%20design">PCB Design</option>
                <option value="pcb%20soldering">PCB Soldering</option>
                <option value="php">PHP</option>
                <option value="php%20development">PHP Development</option>
                <option value="prototyping">PROTOTYPING</option>
                <option value="ptc%20creo">PTC Creo</option>
                <option value="painting">Painting</option>
                <option value="parallel%20thinking">Parallel Thinking</option>
                <option value="pattern%20making">Pattern making</option>
                <option value="performance%20management%20system">Performance Management System</option>
                <option value="petroleum%20engineering">Petroleum Engineering</option>
                <option value="pharmaceutical">Pharmaceutical</option>
                <option value="pharmacovigilance">Pharmacovigilance</option>
                <option value="photography">Photography</option>
                <option value="physics">Physics</option>
                <option value="pinterest%20marketing">Pinterest Marketing</option>
                <option value="political%2Feconomics%2Fpolicy%20research">Political/Economics/Policy Research</option>
                <option value="postgresql">PostgreSQL</option>
                <option value="postman">Postman</option>
                <option value="power%20bi">Power BI</option>
                <option value="prioritization">Prioritization</option>
                <option value="problem%20solving">Problem Solving</option>
                <option value="product%20lifecycle%20management(plm)">Product Lifecycle Management(PLM)</option>
                <option value="product">Product Management</option>
                <option value="product%20management">Product Management</option>
                <option value="product%20strategy">Product Strategy</option>
                <option value="programming">Programming</option>
                <option value="project%20management">Project Management</option>
                <option value="proofreading">Proofreading</option>
                <option value="prospecting">Prospecting</option>
                <option value="psychology">Psychology</option>
                <option value="pr">Public Relations (PR)</option>
                <option value="punjabi%20proficiency%20(spoken)">Punjabi Proficiency (Spoken)</option>
                <option value="python">Python</option>
                <option value="python%2Fdjango">Python/Django Development</option>
                <option value="quality%20analyst">Quality Analyst</option>
                <option value="quality%20assurance%2Fquality%20control%20(qa%2Fqc)">Quality Assurance/Quality Control (QA/QC)</option>
                <option value="quantity%20survey%20(qs)">Quantity Survey (QS)</option>
                <option value="r%20programming">R Programming</option>
                <option value="rest%20api">REST API</option>
                <option value="rapid%20prototyping">Rapid Prototyping</option>
                <option value="raspberry%20pi">Raspberry Pi</option>
                <option value="react">React</option>
                <option value="react%20native">React Native</option>
                <option value="reactjs">ReactJS</option>
                <option value="reaction%20commerce">Reaction Commerce</option>
                <option value="reconnaissance%20survey">Reconnaissance Survey</option>
                <option value="recruitment">Recruitment</option>
                <option value="redux">Redux</option>
                <option value="report%20writing">Report Writing</option>
                <option value="research%20and%20analytics">Research and Analytics</option>
                <option value="responsive%20design">Responsive Design</option>
                <option value="rhino">Rhino</option>
                <option value="robotic%20process%20automation%20(rpa)">Robotic Process Automation (RPA)</option>
                <option value="robotics">Robotics</option>
                <option value="ruby%20on%20rails">Ruby on Rails</option>
                <option value="rust">Rust</option>
                <option value="sap">SAP</option>
                <option value="scss">SCSS</option>
                <option value="sql">SQL</option>
                <option value="staad.pro">STAAD.Pro</option>
                <option value="star-ccm%2B">STAR-CCM+</option>
                <option value="system%20administrator">SYSTEM ADMINISTRATOR</option>
                <option value="sales">Sales</option>
                <option value="sales%20pitch">Sales pitch</option>
                <option value="salesforce">Salesforce</option>
                <option value="sass">Sass</option>
                <option value="science">Science</option>
                <option value="search%20engine%20marketing%20(sem)">Search Engine Marketing (SEM)</option>
                <option value="search%20engine%20optimization%20(seo)">Search Engine Optimization (SEO)</option>
                <option value="selenium">Selenium</option>
                <option value="sharepoint">SharePoint</option>
                <option value="shell%20scripting">Shell Scripting</option>
                <option value="simulink">Simulink</option>
                <option value="sindhi%20proficiency(spoken)">Sindhi Proficiency(Spoken)</option>
                <option value="sindhi%20proficiency(written)">Sindhi Proficiency(Written)</option>
                <option value="six%20sigma">Six Sigma</option>
                <option value="sketch">Sketch</option>
                <option value="sketching">Sketching</option>
                <option value="social%20media%20marketing">Social Media Marketing</option>
                <option value="social%20work">Social Work</option>
                <option value="software%20development">Software Development</option>
                <option value="software%20testing">Software Testing</option>
                <option value="solidworks">SolidWorks</option>
                <option value="sony%20vegas%20pro">Sony Vegas Pro</option>
                <option value="spanish%20proficiency(spoken)">Spanish Proficiency(Spoken)</option>
                <option value="spanish%20proficiency(written)">Spanish Proficiency(Written)</option>
                <option value="sports">Sports</option>
                <option value="spring%20mvc">Spring MVC</option>
                <option value="statistical%20modeling">Statistical Modeling</option>
                <option value="statistics">Statistics</option>
                <option value="statutory%20compliances">Statutory compliances</option>
                <option value="stock%20trading">Stock Trading</option>
                <option value="stock%2Fmarket%20trading">Stock/Market Trading</option>
                <option value="storyboarding">Storyboarding</option>
                <option value="strategy">Strategy</option>
                <option value="stripe%20payment%20api">Stripe Payment API</option>
                <option value="subject%20matter%20expert%20(sme)">Subject Matter Expert (SME)</option>
                <option value="supply%20chain%20management%20(scm)">Supply Chain Management (SCM)</option>
                <option value="swift">Swift</option>
                <option value="system%20biology">System Biology</option>
                <option value="tableau">Tableau</option>
                <option value="tailwind%20css">Tailwind CSS</option>
                <option value="talent%20acquisition">Talent Acquisition</option>
                <option value="tamil%20proficiency%20(spoken)">Tamil Proficiency (Spoken)</option>
                <option value="tamil%20proficiency%20(written)">Tamil Proficiency (Written)</option>
                <option value="teaching">Teaching</option>
                <option value="telecalling">Telecalling</option>
                <option value="telugu%20proficiency%20(spoken)">Telugu Proficiency (Spoken)</option>
                <option value="telugu%20proficiency%20(written)">Telugu Proficiency (Written)</option>
                <option value="terraform">Terraform</option>
                <option value="time%20management">Time Management</option>
                <option value="transcription">Transcription</option>
                <option value="translation">Translation</option>
                <option value="travel%20and%20tourism">Travel &amp; Tourism</option>
                <option value="travel%20itinerary%20making">Travel Itinerary Making</option>
                <option value="typescript">TypeScript</option>
                <option value="ui%20%26%20ux%20design">UI &amp; UX Design</option>
                <option value="ui%2Fux">UI/UX Design</option>
                <option value="ux%20research">UX Research</option>
                <option value="uipath">UiPath</option>
                <option value="unity%203d">Unity 3D</option>
                <option value="unity%20engine">Unity Engine</option>
                <option value="unreal%20engine">Unreal Engine</option>
                <option value="user%20interface%20(ui)%20development">User Interface (UI) Development</option>
                <option value="vapt">VAPT</option>
                <option value="vs%20code">VS Code</option>
                <option value="video%20editing">Video Editing</option>
                <option value="video%20making">Video Making</option>
                <option value="video%20making%2Fediting">Video Making/Editing</option>
                <option value="videography">Videography</option>
                <option value="visual%20basic%20(vb)">Visual Basic (VB)</option>
                <option value="voice-over%20artist">Voice-over artist</option>
                <option value="voiceover">Voiceover</option>
                <option value="volunteering">Volunteering</option>
                <option value="vue%20js">Vue Js</option>
                <option value="web%20application%20security">Web Application Security</option>
                <option value="web%20development">Web Development</option>
                <option value="webflow">Webflow</option>
                <option value="windows%20mobile%20application%20development">Windows Mobile Application Development</option>
                <option value="wireframing">Wireframing</option>
                <option value="wordpress">WordPress</option>
                <option value="wordpress%20development">Wordpress Development</option>
                <option value="xml">XML</option>
                <option value="xcode">Xcode</option>
                <option value="yii">Yii</option>
                <option value="youtube%20ads">YouTube Ads</option>
                <option value="ios">iOS</option>
                <option value="ios%20app%20development">iOS App Development</option>
                <option value="jquery">jQuery</option>
                <option value="web3.js">web3.js</option>
        
</select><div class="chosen-container chosen-container-multi chosen-with-drop chosen-container-active" title="" id="select_category_chosen" style="width: 0px;"><ul class="chosen-choices">
  <li class="search-field">
    <input class="chosen-search-input default" type="text" autocomplete="off" value="e.g. Marketing" style="width: 119px;" tabindex="4">
  </li>
</ul>
<div class="chosen-drop">
  <ul class="chosen-results" style="display: block;"><li class="active-result highlighted" data-option-array-index="0">.NET</li><li class="active-result" data-option-array-index="1">.NET Development</li><li class="active-result" data-option-array-index="2">3D Printing</li><li class="active-result" data-option-array-index="3">3ds Max</li><li class="active-result" data-option-array-index="4">AJAX</li><li class="active-result" data-option-array-index="5">ANSA</li><li class="active-result" data-option-array-index="6">ANSYS</li><li class="active-result" data-option-array-index="7">APIs</li><li class="active-result" data-option-array-index="8">ARM Microcontroller</li><li class="active-result" data-option-array-index="9">ASP.NET</li><li class="active-result" data-option-array-index="10">Ableton Live</li><li class="active-result" data-option-array-index="11">Accounts</li><li class="active-result" data-option-array-index="12">Acting</li><li class="active-result" data-option-array-index="13">Acting Audition</li><li class="active-result" data-option-array-index="14">Acting technique</li><li class="active-result" data-option-array-index="15">Adobe After Effects</li><li class="active-result" data-option-array-index="16">Adobe Audition</li><li class="active-result" data-option-array-index="17">Adobe Creative Suite</li><li class="active-result" data-option-array-index="18">Adobe Dreamweaver</li><li class="active-result" data-option-array-index="19">Adobe Flash</li><li class="active-result" data-option-array-index="20">Adobe Illustrator</li><li class="active-result" data-option-array-index="21">Adobe Indesign</li><li class="active-result" data-option-array-index="22">Adobe Photoshop</li><li class="active-result" data-option-array-index="23">Adobe Photoshop Lightroom CC</li><li class="active-result" data-option-array-index="24">Adobe Premiere Pro</li><li class="active-result" data-option-array-index="25">Adobe XD</li><li class="active-result" data-option-array-index="26">Advanced Excel</li><li class="active-result" data-option-array-index="27">Aerospace Engineering</li><li class="active-result" data-option-array-index="28">Agriculture &amp; Food Engineering</li><li class="active-result" data-option-array-index="29">Algorithms</li><li class="active-result" data-option-array-index="30">Allegro Software</li><li class="active-result" data-option-array-index="31">Amazon Web Server (AWS)</li><li class="active-result" data-option-array-index="32">Amazon Web Services (AWS)</li><li class="active-result" data-option-array-index="33">American English</li><li class="active-result" data-option-array-index="34">Analog And Digital Circuits</li><li class="active-result" data-option-array-index="35">Analytics</li><li class="active-result" data-option-array-index="36">Anchoring</li><li class="active-result" data-option-array-index="37">Android</li><li class="active-result" data-option-array-index="38">Android App Development</li><li class="active-result" data-option-array-index="39">Angular 2.0</li><li class="active-result" data-option-array-index="40">Angular 7.0</li><li class="active-result" data-option-array-index="41">Angular.js Development</li><li class="active-result" data-option-array-index="42">AngularJS</li><li class="active-result" data-option-array-index="43">Animation</li><li class="active-result" data-option-array-index="44">Apache</li><li class="active-result" data-option-array-index="45">ArcGIS</li><li class="active-result" data-option-array-index="46">Architecture</li><li class="active-result" data-option-array-index="47">Arduino</li><li class="active-result" data-option-array-index="48">Articulate 360</li><li class="active-result" data-option-array-index="49">Articulate Storyline</li><li class="active-result" data-option-array-index="50">Artificial Intelligence (AI)</li><li class="active-result" data-option-array-index="51">Artificial intelligence</li><li class="active-result" data-option-array-index="52">Assamese Proficiency (Spoken)</li><li class="active-result" data-option-array-index="53">Assamese Proficiency (Written)</li><li class="active-result" data-option-array-index="54">Atmel AVR</li><li class="active-result" data-option-array-index="55">Audacity</li><li class="active-result" data-option-array-index="56">Audio Editing</li><li class="active-result" data-option-array-index="57">Audio Making</li><li class="active-result" data-option-array-index="58">Audio Making/Editing</li><li class="active-result" data-option-array-index="59">Auditing</li><li class="active-result" data-option-array-index="60">AutoCAD</li><li class="active-result" data-option-array-index="61">Autodesk 123D design</li><li class="active-result" data-option-array-index="62">Autodesk Alias</li><li class="active-result" data-option-array-index="63">Autodesk CFD</li><li class="active-result" data-option-array-index="64">Autodesk Fusion 360</li><li class="active-result" data-option-array-index="65">Autodesk Inventor</li><li class="active-result" data-option-array-index="66">Autodesk Maya</li><li class="active-result" data-option-array-index="67">Autodesk Revit</li><li class="active-result" data-option-array-index="68">Autodesk SketchBook</li><li class="active-result" data-option-array-index="69">Automobile Engineering</li><li class="active-result" data-option-array-index="70">BIM (Building Information Modeling)</li><li class="active-result" data-option-array-index="71">Backend Development</li><li class="active-result" data-option-array-index="72">Bank</li><li class="active-result" data-option-array-index="73">Bash</li><li class="active-result" data-option-array-index="74">Bengali Proficiency (Spoken)</li><li class="active-result" data-option-array-index="75">Bengali Proficiency (Written)</li><li class="active-result" data-option-array-index="76">Big Data</li><li class="active-result" data-option-array-index="77">Bioinformatics</li><li class="active-result" data-option-array-index="78">Biology</li><li class="active-result" data-option-array-index="79">Biotechnology Engineering</li><li class="active-result" data-option-array-index="80">Blender 3D</li><li class="active-result" data-option-array-index="81">Blockchain</li><li class="active-result" data-option-array-index="82">Blockchain Development</li><li class="active-result" data-option-array-index="83">Blogging</li><li class="active-result" data-option-array-index="84">Bodo Proficiency(Spoken)</li><li class="active-result" data-option-array-index="85">Bodo Proficiency(Written)</li><li class="active-result" data-option-array-index="86">Bootstrap</li><li class="active-result" data-option-array-index="87">Brand Management</li><li class="active-result" data-option-array-index="88">British English</li><li class="active-result" data-option-array-index="89">Business Analysis</li><li class="active-result" data-option-array-index="90">Business Development</li><li class="active-result" data-option-array-index="91">Business Research</li><li class="active-result" data-option-array-index="92">Business/MBA</li><li class="active-result" data-option-array-index="93">C Programming</li><li class="active-result" data-option-array-index="94">C#</li><li class="active-result" data-option-array-index="95">C#.NET</li><li class="active-result" data-option-array-index="96">C++ Programming</li><li class="active-result" data-option-array-index="97">CA Articleship</li><li class="active-result" data-option-array-index="98">CAD</li><li class="active-result" data-option-array-index="99">CAD Design</li><li class="active-result" data-option-array-index="100">CAM</li><li class="active-result" data-option-array-index="101">CCNA</li><li class="active-result" data-option-array-index="102">CI/CD</li><li class="active-result" data-option-array-index="103">CLO3D</li><li class="active-result" data-option-array-index="104">CMA Articleship</li><li class="active-result" data-option-array-index="105">CMS</li><li class="active-result" data-option-array-index="106">CNC Programming</li><li class="active-result" data-option-array-index="107">COMSOL</li><li class="active-result" data-option-array-index="108">CONVERGE</li><li class="active-result" data-option-array-index="109">CRM</li><li class="active-result" data-option-array-index="110">CS Articleship</li><li class="active-result" data-option-array-index="111">CSS</li><li class="active-result" data-option-array-index="112">Calligraphy</li><li class="active-result" data-option-array-index="113">Campus Ambassador</li><li class="active-result" data-option-array-index="114">Canva</li><li class="active-result" data-option-array-index="115">Catia</li><li class="active-result" data-option-array-index="116">Chartered Accountancy (CA)</li><li class="active-result" data-option-array-index="117">Chemical Engineering</li><li class="active-result" data-option-array-index="118">Chemistry</li><li class="active-result" data-option-array-index="119">Cinematography</li><li class="active-result" data-option-array-index="120">Circuit Design</li><li class="active-result" data-option-array-index="121">Civil Engineering</li><li class="active-result" data-option-array-index="122">Client Relationship</li><li class="active-result" data-option-array-index="123">Client Servicing</li><li class="active-result" data-option-array-index="124">Client interaction</li><li class="active-result" data-option-array-index="125">Clip Studio Paint</li><li class="active-result" data-option-array-index="126">Cloud Computing</li><li class="active-result" data-option-array-index="127">Cloud Firestore</li><li class="active-result" data-option-array-index="128">CodeIgniter</li><li class="active-result" data-option-array-index="129">Colour Theory for Designers</li><li class="active-result" data-option-array-index="130">Commerce</li><li class="active-result" data-option-array-index="131">Company Secretary (CS)</li><li class="active-result" data-option-array-index="132">Compensation management</li><li class="active-result" data-option-array-index="133">Computational Neuroscience</li><li class="active-result" data-option-array-index="134">Computer Networking</li><li class="active-result" data-option-array-index="135">Computer Networks</li><li class="active-result" data-option-array-index="136">Computer Science</li><li class="active-result" data-option-array-index="137">Computer Vision</li><li class="active-result" data-option-array-index="138">Content Marketing</li><li class="active-result" data-option-array-index="139">Content Writing</li><li class="active-result" data-option-array-index="140">Copywriting</li><li class="active-result" data-option-array-index="141">CorelDRAW</li><li class="active-result" data-option-array-index="142">Creative Design</li><li class="active-result" data-option-array-index="143">Creative Writing</li><li class="active-result" data-option-array-index="144">Culinary Arts</li><li class="active-result" data-option-array-index="145">Customer Service</li><li class="active-result" data-option-array-index="146">Cyber Security</li><li class="active-result" data-option-array-index="147">Dart</li><li class="active-result" data-option-array-index="148">Data Analysis</li><li class="active-result" data-option-array-index="149">Data Analytics</li><li class="active-result" data-option-array-index="150">Data Entry</li><li class="active-result" data-option-array-index="151">Data Science</li><li class="active-result" data-option-array-index="152">Data Structures</li><li class="active-result" data-option-array-index="153">Database Building</li><li class="active-result" data-option-array-index="154">Database Testing</li><li class="active-result" data-option-array-index="155">Deep Learning</li><li class="active-result" data-option-array-index="156">Design</li><li class="active-result" data-option-array-index="157">Design Thinking</li><li class="active-result" data-option-array-index="158">DevOps</li><li class="active-result" data-option-array-index="159">Dietetics/Nutrition</li><li class="active-result" data-option-array-index="160">Digital Advertising</li><li class="active-result" data-option-array-index="161">Digital Art</li><li class="active-result" data-option-array-index="162">Digital Marketing</li><li class="active-result" data-option-array-index="163">Digital Signal Processing</li><li class="active-result" data-option-array-index="164">DigitalOcean</li><li class="active-result" data-option-array-index="165">Display Advertising</li><li class="active-result" data-option-array-index="166">Django</li><li class="active-result" data-option-array-index="167">Docker</li><li class="active-result" data-option-array-index="168">Drupal</li><li class="active-result" data-option-array-index="169">EAGLE</li><li class="active-result" data-option-array-index="170">ERP Implementation and Deployment</li><li class="active-result" data-option-array-index="171">Eclipse (IDE)</li><li class="active-result" data-option-array-index="172">Econometrics</li><li class="active-result" data-option-array-index="173">Economics</li><li class="active-result" data-option-array-index="174">Editorial</li><li class="active-result" data-option-array-index="175">Effective Communication</li><li class="active-result" data-option-array-index="176">Elasticsearch</li><li class="active-result" data-option-array-index="177">Electrical Engineering</li><li class="active-result" data-option-array-index="178">ElectronJS</li><li class="active-result" data-option-array-index="179">Electronics Engineering</li><li class="active-result" data-option-array-index="180">Email Marketing</li><li class="active-result" data-option-array-index="181">Embedded Systems</li><li class="active-result" data-option-array-index="182">Employment engagement</li><li class="active-result" data-option-array-index="183">Energy Science &amp; Engineering</li><li class="active-result" data-option-array-index="184">Engineering</li><li class="active-result" data-option-array-index="185">Engineering Design</li><li class="active-result" data-option-array-index="186">Engineering Drawing</li><li class="active-result" data-option-array-index="187">Engineering Physics</li><li class="active-result" data-option-array-index="188">Engineering Surveying</li><li class="active-result" data-option-array-index="189">English Proficiency (Spoken)</li><li class="active-result" data-option-array-index="190">English Proficiency (Written)</li><li class="active-result" data-option-array-index="191">Enterprise Resource Planning(ERP)</li><li class="active-result" data-option-array-index="192">Environmental Sciences</li><li class="active-result" data-option-array-index="193">Estimation (estimating)</li><li class="active-result" data-option-array-index="194">Ethereum</li><li class="active-result" data-option-array-index="195">Ethical Hacking</li><li class="active-result" data-option-array-index="196">Event Management</li><li class="active-result" data-option-array-index="197">Express.js</li><li class="active-result" data-option-array-index="198">FL Studio (formerly known as FruityLoops)</li><li class="active-result" data-option-array-index="199">Facebook Ads</li><li class="active-result" data-option-array-index="200">Facebook Marketing</li><li class="active-result" data-option-array-index="201">Fashion Design</li><li class="active-result" data-option-array-index="202">Fashion Designing</li><li class="active-result" data-option-array-index="203">Fashion Styling</li><li class="active-result" data-option-array-index="204">FastAPI</li><li class="active-result" data-option-array-index="205">Figma</li><li class="active-result" data-option-array-index="206">Film Making</li><li class="active-result" data-option-array-index="207">Final Cut Pro</li><li class="active-result" data-option-array-index="208">Finance</li><li class="active-result" data-option-array-index="209">Financial Modeling</li><li class="active-result" data-option-array-index="210">Financial literacy</li><li class="active-result" data-option-array-index="211">Firebase</li><li class="active-result" data-option-array-index="212">Firebase Cloud Messaging</li><li class="active-result" data-option-array-index="213">Flask</li><li class="active-result" data-option-array-index="214">Flutter</li><li class="active-result" data-option-array-index="215">Flutter Development</li><li class="active-result" data-option-array-index="216">French Proficiency (spoken)</li><li class="active-result" data-option-array-index="217">French Proficiency (written)</li><li class="active-result" data-option-array-index="218">Front End Development</li><li class="active-result" data-option-array-index="219">Full Stack Development</li><li class="active-result" data-option-array-index="220">Fundraising</li><li class="active-result" data-option-array-index="221">GIMP</li><li class="active-result" data-option-array-index="222">GUI Testing</li><li class="active-result" data-option-array-index="223">Game Design</li><li class="active-result" data-option-array-index="224">Game Development</li><li class="active-result" data-option-array-index="225">General Management</li><li class="active-result" data-option-array-index="226">German Proficiency (Spoken)</li><li class="active-result" data-option-array-index="227">German Proficiency (Written)</li><li class="active-result" data-option-array-index="228">Git</li><li class="active-result" data-option-array-index="229">GitHub</li><li class="active-result" data-option-array-index="230">Golang</li><li class="active-result" data-option-array-index="231">Google AdWords</li><li class="active-result" data-option-array-index="232">Google Analytics</li><li class="active-result" data-option-array-index="233">Google Cloud Computing</li><li class="active-result" data-option-array-index="234">Google SketchUp </li><li class="active-result" data-option-array-index="235">Google Suite (G Suite)</li><li class="active-result" data-option-array-index="236">Google Workspace</li><li class="active-result" data-option-array-index="237">Government</li><li class="active-result" data-option-array-index="238">Graphic Design</li><li class="active-result" data-option-array-index="239">Guitar</li><li class="active-result" data-option-array-index="240">Gujarati Proficiency (Spoken)</li><li class="active-result" data-option-array-index="241">Gujarati Proficiency (Written)</li><li class="active-result" data-option-array-index="242">HR Analytics</li><li class="active-result" data-option-array-index="243">HR branding</li><li class="active-result" data-option-array-index="244">HRIS</li><li class="active-result" data-option-array-index="245">HTML</li><li class="active-result" data-option-array-index="246">HTML&amp;CSS</li><li class="active-result" data-option-array-index="247">Hadoop</li><li class="active-result" data-option-array-index="248">HelioScope</li><li class="active-result" data-option-array-index="249">Hibernate (Java)</li><li class="active-result" data-option-array-index="250">Hindi Proficiency (Spoken)</li><li class="active-result" data-option-array-index="251">Hindi Proficiency (Written)</li><li class="active-result" data-option-array-index="252">History</li><li class="active-result" data-option-array-index="253">Holiday Package Design</li><li class="active-result" data-option-array-index="254">Hospitality</li><li class="active-result" data-option-array-index="255">Hotel Management</li><li class="active-result" data-option-array-index="256">Human Resources (HR)</li><li class="active-result" data-option-array-index="257">Humanities</li><li class="active-result" data-option-array-index="258">Hyperledger</li><li class="active-result" data-option-array-index="259">Image Processing</li><li class="active-result" data-option-array-index="260">Industrial &amp; Production Engineering</li><li class="active-result" data-option-array-index="261">Industrial Design</li><li class="active-result" data-option-array-index="262">Industrial automation</li><li class="active-result" data-option-array-index="263">Information Technology</li><li class="active-result" data-option-array-index="264">Information architecture</li><li class="active-result" data-option-array-index="265">Inkscape</li><li class="active-result" data-option-array-index="266">Instagram Marketing</li><li class="active-result" data-option-array-index="267">Instrumentation &amp; Control Engineering</li><li class="active-result" data-option-array-index="268">Interior Design</li><li class="active-result" data-option-array-index="269">International</li><li class="active-result" data-option-array-index="270">Internet of Things (IoT)</li><li class="active-result" data-option-array-index="271">Interpersonal skills</li><li class="active-result" data-option-array-index="272">Investing</li><li class="active-result" data-option-array-index="273">Ionic</li><li class="active-result" data-option-array-index="274">J2EE</li><li class="active-result" data-option-array-index="275">JSON</li><li class="active-result" data-option-array-index="276">JSP</li><li class="active-result" data-option-array-index="277">Java</li><li class="active-result" data-option-array-index="278">JavaScript</li><li class="active-result" data-option-array-index="279">Javascript Development</li><li class="active-result" data-option-array-index="280">Jenkins</li><li class="active-result" data-option-array-index="281">Jira</li><li class="active-result" data-option-array-index="282">Journalism</li><li class="active-result" data-option-array-index="283">Kannada</li><li class="active-result" data-option-array-index="284">Kannada Proficiency (Spoken)</li><li class="active-result" data-option-array-index="285">Kannada Proficiency (Written)</li><li class="active-result" data-option-array-index="286">Kashmiri Proficiency (Spoken)</li><li class="active-result" data-option-array-index="287">Kashmiri Proficiency (written)</li><li class="active-result" data-option-array-index="288">KeyShot</li><li class="active-result" data-option-array-index="289">Konkani Proficiency (Spoken)</li><li class="active-result" data-option-array-index="290">Korean Proficiency (Spoken)</li><li class="active-result" data-option-array-index="291">Korean Proficiency (Written)</li><li class="active-result" data-option-array-index="292">Kotlin</li><li class="active-result" data-option-array-index="293">Kubernetes</li><li class="active-result" data-option-array-index="294">LARAVEL</li><li class="active-result" data-option-array-index="295">LaTeX</li><li class="active-result" data-option-array-index="296">Labour laws</li><li class="active-result" data-option-array-index="297">Law</li><li class="active-result" data-option-array-index="298">Lead Generation</li><li class="active-result" data-option-array-index="299">Legal Research</li><li class="active-result" data-option-array-index="300">Linear Programming</li><li class="active-result" data-option-array-index="301">LinkedIn Marketing</li><li class="active-result" data-option-array-index="302">Linux</li><li class="active-result" data-option-array-index="303">MATLAB</li><li class="active-result" data-option-array-index="304">MEAN/MERN Stack</li><li class="active-result" data-option-array-index="305">MS SQL Server</li><li class="active-result" data-option-array-index="306">MS-Excel</li><li class="active-result" data-option-array-index="307">MS-Office</li><li class="active-result" data-option-array-index="308">MS-PowerPoint</li><li class="active-result" data-option-array-index="309">MS-Word</li><li class="active-result" data-option-array-index="310">Machine Learning</li><li class="active-result" data-option-array-index="311">Malayalam Proficiency (Spoken)</li><li class="active-result" data-option-array-index="312">Malayalam Proficiency (Written)</li><li class="active-result" data-option-array-index="313">Manipuri Proficiency (Spoken)</li><li class="active-result" data-option-array-index="314">Manipuri Proficiency (Written)</li><li class="active-result" data-option-array-index="315">Manpower Planning</li><li class="active-result" data-option-array-index="316">Manual Testing</li><li class="active-result" data-option-array-index="317">Manufacturing Engineering</li><li class="active-result" data-option-array-index="318">Marathi Proficiency(Spoken)</li><li class="active-result" data-option-array-index="319">Marathi Proficiency(Written)</li><li class="active-result" data-option-array-index="320">Market Analysis</li><li class="active-result" data-option-array-index="321">Market research</li><li class="active-result" data-option-array-index="322">Market/Business Research</li><li class="active-result" data-option-array-index="323">Marketing</li><li class="active-result" data-option-array-index="324">Marketing Campaigns </li><li class="active-result" data-option-array-index="325">Marketing Programs </li><li class="active-result" data-option-array-index="326">Marketing Strategies </li><li class="active-result" data-option-array-index="327">Material Science</li><li class="active-result" data-option-array-index="328">Mathematics</li><li class="active-result" data-option-array-index="329">Mathematics &amp; Computing</li><li class="active-result" data-option-array-index="330">Mechanical Engineering</li><li class="active-result" data-option-array-index="331">Mechatronics</li><li class="active-result" data-option-array-index="332">Media</li><li class="active-result" data-option-array-index="333">Medicine</li><li class="active-result" data-option-array-index="334">Merchandise Design</li><li class="active-result" data-option-array-index="335">Metallurgical Engineering</li><li class="active-result" data-option-array-index="336">Microsoft Azure</li><li class="active-result" data-option-array-index="337">Microsoft PowerApps</li><li class="active-result" data-option-array-index="338">Microsoft Project</li><li class="active-result" data-option-array-index="339">Microsoft Visual Studio</li><li class="active-result" data-option-array-index="340">Mobile App Development</li><li class="active-result" data-option-array-index="341">Model View Controller(MVC)</li><li class="active-result" data-option-array-index="342">Molecular Biology Techniques</li><li class="active-result" data-option-array-index="343">Molecular Medicine</li><li class="active-result" data-option-array-index="344">MongoDB</li><li class="active-result" data-option-array-index="345">Motion Graphics</li><li class="active-result" data-option-array-index="346">Music</li><li class="active-result" data-option-array-index="347">MySQL</li><li class="active-result" data-option-array-index="348">NGO</li><li class="active-result" data-option-array-index="349">NX Siemens (formerly Unigraphics NX)</li><li class="active-result" data-option-array-index="350">Natural Language Processing (NLP)</li><li class="active-result" data-option-array-index="351">Naval Architecture and Ocean Engineeering</li><li class="active-result" data-option-array-index="352">Negotiation &amp; Problem-solving</li><li class="active-result" data-option-array-index="353">Network Engineering</li><li class="active-result" data-option-array-index="354">Neural Networks</li><li class="active-result" data-option-array-index="355">Next Generation Sequencing (NGS)</li><li class="active-result" data-option-array-index="356">Next.js</li><li class="active-result" data-option-array-index="357">Nginx</li><li class="active-result" data-option-array-index="358">NoSQL</li><li class="active-result" data-option-array-index="359">Node.js</li><li class="active-result" data-option-array-index="360">Node.js Development</li><li class="active-result" data-option-array-index="361">Objective C</li><li class="active-result" data-option-array-index="362">Odia Proficiency(Spoken)</li><li class="active-result" data-option-array-index="363">Odia Proficiency(Written)</li><li class="active-result" data-option-array-index="364">Odoo</li><li class="active-result" data-option-array-index="365">Online Teaching</li><li class="active-result" data-option-array-index="366">OpenCV</li><li class="active-result" data-option-array-index="367">Operations</li><li class="active-result" data-option-array-index="368">Oracle</li><li class="active-result" data-option-array-index="369">PCB Design</li><li class="active-result" data-option-array-index="370">PCB Soldering</li><li class="active-result" data-option-array-index="371">PHP</li><li class="active-result" data-option-array-index="372">PHP Development</li><li class="active-result" data-option-array-index="373">PROTOTYPING</li><li class="active-result" data-option-array-index="374">PTC Creo</li><li class="active-result" data-option-array-index="375">Painting</li><li class="active-result" data-option-array-index="376">Parallel Thinking</li><li class="active-result" data-option-array-index="377">Pattern making</li><li class="active-result" data-option-array-index="378">Performance Management System</li><li class="active-result" data-option-array-index="379">Petroleum Engineering</li><li class="active-result" data-option-array-index="380">Pharmaceutical</li><li class="active-result" data-option-array-index="381">Pharmacovigilance</li><li class="active-result" data-option-array-index="382">Photography</li><li class="active-result" data-option-array-index="383">Physics</li><li class="active-result" data-option-array-index="384">Pinterest Marketing</li><li class="active-result" data-option-array-index="385">Political/Economics/Policy Research</li><li class="active-result" data-option-array-index="386">PostgreSQL</li><li class="active-result" data-option-array-index="387">Postman</li><li class="active-result" data-option-array-index="388">Power BI</li><li class="active-result" data-option-array-index="389">Prioritization</li><li class="active-result" data-option-array-index="390">Problem Solving</li><li class="active-result" data-option-array-index="391">Product Lifecycle Management(PLM)</li><li class="active-result" data-option-array-index="392">Product Management</li><li class="active-result" data-option-array-index="393">Product Management</li><li class="active-result" data-option-array-index="394">Product Strategy</li><li class="active-result" data-option-array-index="395">Programming</li><li class="active-result" data-option-array-index="396">Project Management</li><li class="active-result" data-option-array-index="397">Proofreading</li><li class="active-result" data-option-array-index="398">Prospecting</li><li class="active-result" data-option-array-index="399">Psychology</li><li class="active-result" data-option-array-index="400">Public Relations (PR)</li><li class="active-result" data-option-array-index="401">Punjabi Proficiency (Spoken)</li><li class="active-result" data-option-array-index="402">Python</li><li class="active-result" data-option-array-index="403">Python/Django Development</li><li class="active-result" data-option-array-index="404">Quality Analyst</li><li class="active-result" data-option-array-index="405">Quality Assurance/Quality Control (QA/QC)</li><li class="active-result" data-option-array-index="406">Quantity Survey (QS)</li><li class="active-result" data-option-array-index="407">R Programming</li><li class="active-result" data-option-array-index="408">REST API</li><li class="active-result" data-option-array-index="409">Rapid Prototyping</li><li class="active-result" data-option-array-index="410">Raspberry Pi</li><li class="active-result" data-option-array-index="411">React</li><li class="active-result" data-option-array-index="412">React Native</li><li class="active-result" data-option-array-index="413">ReactJS</li><li class="active-result" data-option-array-index="414">Reaction Commerce</li><li class="active-result" data-option-array-index="415">Reconnaissance Survey</li><li class="active-result" data-option-array-index="416">Recruitment</li><li class="active-result" data-option-array-index="417">Redux</li><li class="active-result" data-option-array-index="418">Report Writing</li><li class="active-result" data-option-array-index="419">Research and Analytics</li><li class="active-result" data-option-array-index="420">Responsive Design</li><li class="active-result" data-option-array-index="421">Rhino</li><li class="active-result" data-option-array-index="422">Robotic Process Automation (RPA)</li><li class="active-result" data-option-array-index="423">Robotics</li><li class="active-result" data-option-array-index="424">Ruby on Rails</li><li class="active-result" data-option-array-index="425">Rust</li><li class="active-result" data-option-array-index="426">SAP</li><li class="active-result" data-option-array-index="427">SCSS</li><li class="active-result" data-option-array-index="428">SQL</li><li class="active-result" data-option-array-index="429">STAAD.Pro</li><li class="active-result" data-option-array-index="430">STAR-CCM+</li><li class="active-result" data-option-array-index="431">SYSTEM ADMINISTRATOR</li><li class="active-result" data-option-array-index="432">Sales</li><li class="active-result" data-option-array-index="433">Sales pitch</li><li class="active-result" data-option-array-index="434">Salesforce</li><li class="active-result" data-option-array-index="435">Sass</li><li class="active-result" data-option-array-index="436">Science</li><li class="active-result" data-option-array-index="437">Search Engine Marketing (SEM)</li><li class="active-result" data-option-array-index="438">Search Engine Optimization (SEO)</li><li class="active-result" data-option-array-index="439">Selenium</li><li class="active-result" data-option-array-index="440">SharePoint</li><li class="active-result" data-option-array-index="441">Shell Scripting</li><li class="active-result" data-option-array-index="442">Simulink</li><li class="active-result" data-option-array-index="443">Sindhi Proficiency(Spoken)</li><li class="active-result" data-option-array-index="444">Sindhi Proficiency(Written)</li><li class="active-result" data-option-array-index="445">Six Sigma</li><li class="active-result" data-option-array-index="446">Sketch</li><li class="active-result" data-option-array-index="447">Sketching</li><li class="active-result" data-option-array-index="448">Social Media Marketing</li><li class="active-result" data-option-array-index="449">Social Work</li><li class="active-result" data-option-array-index="450">Software Development</li><li class="active-result" data-option-array-index="451">Software Testing</li><li class="active-result" data-option-array-index="452">SolidWorks</li><li class="active-result" data-option-array-index="453">Sony Vegas Pro</li><li class="active-result" data-option-array-index="454">Spanish Proficiency(Spoken)</li><li class="active-result" data-option-array-index="455">Spanish Proficiency(Written)</li><li class="active-result" data-option-array-index="456">Sports</li><li class="active-result" data-option-array-index="457">Spring MVC</li><li class="active-result" data-option-array-index="458">Statistical Modeling</li><li class="active-result" data-option-array-index="459">Statistics</li><li class="active-result" data-option-array-index="460">Statutory compliances</li><li class="active-result" data-option-array-index="461">Stock Trading</li><li class="active-result" data-option-array-index="462">Stock/Market Trading</li><li class="active-result" data-option-array-index="463">Storyboarding</li><li class="active-result" data-option-array-index="464">Strategy</li><li class="active-result" data-option-array-index="465">Stripe Payment API</li><li class="active-result" data-option-array-index="466">Subject Matter Expert (SME)</li><li class="active-result" data-option-array-index="467">Supply Chain Management (SCM)</li><li class="active-result" data-option-array-index="468">Swift</li><li class="active-result" data-option-array-index="469">System Biology</li><li class="active-result" data-option-array-index="470">Tableau</li><li class="active-result" data-option-array-index="471">Tailwind CSS</li><li class="active-result" data-option-array-index="472">Talent Acquisition</li><li class="active-result" data-option-array-index="473">Tamil Proficiency (Spoken)</li><li class="active-result" data-option-array-index="474">Tamil Proficiency (Written)</li><li class="active-result" data-option-array-index="475">Teaching</li><li class="active-result" data-option-array-index="476">Telecalling</li><li class="active-result" data-option-array-index="477">Telugu Proficiency (Spoken)</li><li class="active-result" data-option-array-index="478">Telugu Proficiency (Written)</li><li class="active-result" data-option-array-index="479">Terraform</li><li class="active-result" data-option-array-index="480">Time Management</li><li class="active-result" data-option-array-index="481">Transcription</li><li class="active-result" data-option-array-index="482">Translation</li><li class="active-result" data-option-array-index="483">Travel &amp; Tourism</li><li class="active-result" data-option-array-index="484">Travel Itinerary Making</li><li class="active-result" data-option-array-index="485">TypeScript</li><li class="active-result" data-option-array-index="486">UI &amp; UX Design</li><li class="active-result" data-option-array-index="487">UI/UX Design</li><li class="active-result" data-option-array-index="488">UX Research</li><li class="active-result" data-option-array-index="489">UiPath</li><li class="active-result" data-option-array-index="490">Unity 3D</li><li class="active-result" data-option-array-index="491">Unity Engine</li><li class="active-result" data-option-array-index="492">Unreal Engine</li><li class="active-result" data-option-array-index="493">User Interface (UI) Development</li><li class="active-result" data-option-array-index="494">VAPT</li><li class="active-result" data-option-array-index="495">VS Code</li><li class="active-result" data-option-array-index="496">Video Editing</li><li class="active-result" data-option-array-index="497">Video Making</li><li class="active-result" data-option-array-index="498">Video Making/Editing</li><li class="active-result" data-option-array-index="499">Videography</li><li class="active-result" data-option-array-index="500">Visual Basic (VB)</li><li class="active-result" data-option-array-index="501">Voice-over artist</li><li class="active-result" data-option-array-index="502">Voiceover</li><li class="active-result" data-option-array-index="503">Volunteering</li><li class="active-result" data-option-array-index="504">Vue Js</li><li class="active-result" data-option-array-index="505">Web Application Security</li><li class="active-result" data-option-array-index="506">Web Development</li><li class="active-result" data-option-array-index="507">Webflow</li><li class="active-result" data-option-array-index="508">Windows Mobile Application Development</li><li class="active-result" data-option-array-index="509">Wireframing</li><li class="active-result" data-option-array-index="510">WordPress</li><li class="active-result" data-option-array-index="511">Wordpress Development</li><li class="active-result" data-option-array-index="512">XML</li><li class="active-result" data-option-array-index="513">Xcode</li><li class="active-result" data-option-array-index="514">Yii</li><li class="active-result" data-option-array-index="515">YouTube Ads</li><li class="active-result" data-option-array-index="516">iOS</li><li class="active-result" data-option-array-index="517">iOS App Development</li><li class="active-result" data-option-array-index="518">jQuery</li><li class="active-result" data-option-array-index="519">web3.js</li></ul>
</div></div>
<div class="chosen-container chosen-container-multi chosen-with-drop" title="" id="select_category_chosen_temp" style="display: none;">
    <ul class="chosen-choices">
                    <li class="search-field">
                <input class="chosen-search-input default" type="text" autocomplete="off" value="e.g. Marketing" tabindex="4" style="width: 119px;">
            </li>
            </ul>
</div>"""

# %%
soup2 = BeautifulSoup(source, 'html.parser')

# %%
CategoryOptions =[]

# %%
for tag in soup2.find_all('option', attrs = {}):
    CategoryOptions.append(tag.text)

# %%
link = 'https://internshala.com/internships/'

for i in range(len(CategoryOptions)):    
    CategoryOptions[i] = CategoryOptions[i].replace(" ", '-').lower() + '-internships/'

# %%
CategoryOptions
# Out:
# ['.net-internships/',
#  '.net-development-internships/',
#  '3d-printing-internships/',
#  '3ds-max-internships/',
#  'ajax-internships/',
#  'ansa-internships/',
#  'ansys-internships/',
#  'apis-internships/',
#  'arm-microcontroller-internships/',
#  'asp.net-internships/',
#  'ableton-live-internships/',
#  'accounts-internships/',
#  'acting-internships/',
#  'acting-audition-internships/',
#  'acting-technique-internships/',
#  'adobe-after-effects-internships/',
#  'adobe-audition-internships/',
#  'adobe-creative-suite-internships/',
#  'adobe-dreamweaver-internships/',
#  'adobe-flash-internships/',
#  'adobe-illustrator-internships/',
#  'adobe-indesign-internships/',
#  'adobe-photoshop-internships/',
#  'adobe-photoshop-lightroom-cc-internships/',
#  'adobe-premiere-pro-internships/',
#  'adobe-xd-internships/',
#  'advanced-excel-internships/',
#  'aerospace-engineering-internships/',
#  'agriculture-&-food-engineering-internships/',
#  'algorithms-internships/',
# ...

# %%
import requests

url = "https://geocoding-by-api-ninjas.p.rapidapi.com/v1/geocoding"

querystring = {"city":"Seattle"}

headers = {
	"X-RapidAPI-Key": "763c810bdfmshb9f4669b80c3925p18d818jsn3db5be365864",
	"X-RapidAPI-Host": "geocoding-by-api-ninjas.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
# Out:
# [{'name': 'Seattle', 'latitude': 47.6038321, 'longitude': -122.330062, 'country': 'US', 'state': 'Washington'}, {'name': 'Seattle', 'latitude': 20.7199684, 'longitude': -103.3763286, 'country': 'MX', 'state': 'Jalisco'}, {'name': 'Laurelhurst', 'latitude': 45.5265116, 'longitude': -122.6244677, 'country': 'US', 'state': 'Oregon'}]

# %%
link2 = 'https://us1.locationiq.com/v1/search?key=YOUR_ACCESS_TOKEN&q=SEARCH_STRING&format=json'

data = {
    'key': 'pk.123097f96d326dd4e3d09c11d5029b9f',
    'q': 'Noida, India',
    'format': 'json'
}

response2 = requests.get(link2, params=data)
print(response2.text)
# Out:
# [{"place_id":"1224641","licence":"https:\/\/locationiq.com\/attribution","osm_type":"node","osm_id":"313255437","boundingbox":["28.4106333","28.7306333","77.1672147","77.4872147"],"lat":"28.5706333","lon":"77.3272147","display_name":"Noida, Dadri, Gautam Buddha Nagar District, Uttar Pradesh, 201301, India","class":"place","type":"city","importance":0.6783365652712278,"icon":"https:\/\/locationiq.org\/static\/images\/mapicons\/poi_place_city.p.20.png"}]

# %%
pattern1 = '\"lat\":\"(.\d+.\d+)'
pattern2 = '\"lon\":\"(.\d+.\d+)'

# %%
import re

print(re.findall(pattern1, response2.text)[0])
print(re.findall(pattern2, response2.text)[0])
# Out:
# 28.5706333
# 77.3272147

# %%
import numpy as np
df = pd.DataFrame(
    np.random.randn(1000, 2) / [50, 50] + [37.76, -122.4],
    columns=['lat', 'lon'])

# %%
df2 = pd.DataFrame({
    'lat' : 18.521428,
    'lon' : 73.8544541
}, index = [0])

# %%
df2
# Out:
#          lat        lon
# 0  18.521428  73.854454
